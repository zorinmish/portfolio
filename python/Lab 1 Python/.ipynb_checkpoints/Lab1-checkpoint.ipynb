# %%
import pandas as pd
import numpy as np

data=pd.read_csv('tmdb_5000_movies.csv')

# %%
data.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# max       10.000000  13752.000000

# %%
data.dtypes
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# dtype: object

# %% [markdown]
# Numerical features:
#             budget popularity revenue runtime vote_average vote_count

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
plt.hist(data['popularity'],bins=70)
plt.title('Movies popularity histogram')
plt.xlabel('Popularity')
plt.ylabel('# of movies')
plt.show()

# %%
#числовые поля - продолжительность, бюджет, оценка зрителей, количество оценок

plt.rcParams['figure.figsize'] = 12, 12
fig, axs = plt.subplots(2,2)
fig.suptitle('Numerical Feature Histograms',y=0.95,fontsize=16)

axs[0,0].hist(data['runtime'],bins = 30, color = 'red')
axs[0,0].set_title('Runtime')
axs[0,0].set(xlabel='Minutes')

axs[0,1].hist(data['budget'], bins = 50, color = 'green')
axs[0,1].set_title('Budget')
axs[0,1].set(xlabel = 'US Dollar')

axs[1,0].hist(data['vote_average'], bins = 50, color = 'blue')
axs[1,0].set_title('Average voting')
axs[1,0].set(xlabel = 'Score')

axs[1,1].hist(data['vote_count'], bins = 30, color = 'yellow')
axs[1,1].set_title('Number of votes of single film')
axs[1,1].set(xlabel = "№")

plt.show()

# %%
import json

# Нечисловые поля - количество по жарнам и странам

def dic_count(dataset, field):
    dic = {}
    for el in dataset[field].values:
        test = json.loads(el)
        for key in test:
            if dic.get(key["name"]) is None:
                dic[key["name"]] = 1
            else:
                dic[key["name"]] = dic[key["name"]] + 1
    return dic


# 1
genres = dic_count(data, "genres")
sort_genres = dict(sorted(genres.items()))

fig = plt.figure(figsize=(10, 6))
ax = fig.gca()
ax.bar(list(sort_genres.keys()), list(sort_genres.values()))
ax.set_title('Genres number')
plt.xticks(rotation=45, ha='right')
plt.show()

# 2
countries = dic_count(data, "production_countries")
sort_countries = dict(sorted(countries.items())[:20])

fig = plt.figure(figsize=(10, 6))
ax = fig.gca()
ax.bar(list(sort_countries.keys()), list(sort_countries.values()))
ax.set_title('Production countries')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#функции для вычислений рейтинга фильмов

def calculate_rating_medium(film_score, film_amount):
    if film_score == 0 or film_amount == 0:
        return 0
    v = film_amount
    m= data['vote_count'].quantile(0.75)
    R = film_score
    C = data['vote_average'].mean()
    return (v*R/(v+m))+(m*C/(v+m))

def calculate_rating_mediana(film_score, film_amount):
    if film_score == 0 or film_amount == 0:
        return 0
    v = film_amount
    m= data['vote_count'].quantile(0.75)
    R = film_score
    C = data['vote_average'].median()
    return (v*R/(v+m))+(m*C/(v+m))

def transform1(film):
    return {
        "name": film["title"],
        "score": calculate_rating_medium(film["vote_average"], film["vote_count"])
        }

def transform2(film):
    return {
        "name": film["title"],
        "score": calculate_rating_mediana(film["vote_average"], film["vote_count"])
        }

# %%
# рейтинг Топ-10 с С = среднее

marks = []

for i in range(len(data)):
    res = transform1(data.loc[i])
    if res["score"] is not None:
        marks.append(res)

marks = sorted(marks, key=lambda film: film["score"])
marks.reverse()

for i in range(10):
    print("{}. NAME: '{}' SCORE: {}\n".format(i+1, marks[i]["name"],'%.3f' % marks[i]["score"]))
# Out:
# 1. NAME: 'The Shawshank Redemption' SCORE: 8.302
#
# 2. NAME: 'The Godfather' SCORE: 8.143
#
# 3. NAME: 'Fight Club' SCORE: 8.140
#
# 4. NAME: 'Pulp Fiction' SCORE: 8.122
#
# 5. NAME: 'The Dark Knight' SCORE: 8.078
#
# 6. NAME: 'Forrest Gump' SCORE: 8.021
#
# 7. NAME: 'Inception' SCORE: 7.998
#
# 8. NAME: 'Schindler's List' SCORE: 7.979
#
# 9. NAME: 'Whiplash' SCORE: 7.974
#
# 10. NAME: 'Interstellar' SCORE: 7.972

# %%
# рейтинг Топ-10 с С = медиана

marks = []

for i in range(len(data)):
    res = transform2(data.loc[i])
    if res["score"] is not None:
        marks.append(res)

marks = sorted(marks, key=lambda film: film["score"])
marks.reverse()

for i in range(10):
    print("{}. NAME: '{}' SCORE: {}\n".format(i+1, marks[i]["name"],'%.3f' % marks[i]["score"]))
# Out:
# 1. NAME: 'The Shawshank Redemption' SCORE: 8.310
#
# 2. NAME: 'The Godfather' SCORE: 8.155
#
# 3. NAME: 'Fight Club' SCORE: 8.148
#
# 4. NAME: 'Pulp Fiction' SCORE: 8.131
#
# 5. NAME: 'The Dark Knight' SCORE: 8.084
#
# 6. NAME: 'Forrest Gump' SCORE: 8.030
#
# 7. NAME: 'Inception' SCORE: 8.003
#
# 8. NAME: 'Schindler's List' SCORE: 7.994
#
# 9. NAME: 'Whiplash' SCORE: 7.990
#
# 10. NAME: 'Interstellar' SCORE: 7.979

# %%
# Топ-5 каждого жанра с С = среднее

genres_array = []
ans_dict = dict()
for i in data['genres']:
    ggs = json.loads(i)
    if len(ggs) != 0:
        if ggs[0]["name"] not in genres_array:
            genres_array.append(ggs[0]["name"])
            ans_dict[ggs[0]["name"]] = []

for i in range(len(data)):
    j = data.loc[i]["genres"]
    ggs = json.loads(j)
    if len(ggs) != 0:
        ans_dict[ggs[0]["name"]].append(transform1(data.loc[i]))

for i in genres_array:
    ans_dict[i] = sorted(ans_dict[i], key=lambda film: film["score"])
    ans_dict[i].reverse()

print("Top 5 by genre(mean):\n")
for i in genres_array:
    print("GENRE: {}".format(i))
    for j in range(min(5, len(ans_dict[i]))):
        print("{}. Film: {}       SCORE: {}".format(j+1, ans_dict[i][j]["name"],'%.3f' % ans_dict[i][j]["score"]))
    print('\n')
# Out:
# Top 5 by genre(mean):
#
# GENRE: Action
# 1. Film: Inception       SCORE: 7.998
# 2. Film: Guardians of the Galaxy       SCORE: 7.773
# 3. Film: The Matrix       SCORE: 7.762
# 4. Film: Gladiator       SCORE: 7.684
# 5. Film: Scarface       SCORE: 7.618
#
#
# GENRE: Adventure
# 1. Film: Interstellar       SCORE: 7.972
# 2. Film: The Empire Strikes Back       SCORE: 7.965
# 3. Film: The Lord of the Rings: The Return of the King       SCORE: 7.932
# 4. Film: Star Wars       SCORE: 7.899
# 5. Film: The Lord of the Rings: The Fellowship of the Ring       SCORE: 7.851
#
#
# GENRE: Fantasy
# 1. Film: Spirited Away       SCORE: 7.944
# 2. Film: The Green Mile       SCORE: 7.875
# 3. Film: Howl's Moving Castle       SCORE: 7.631
# 4. Film: Donnie Darko       SCORE: 7.417
# 5. Film: How to Train Your Dragon 2       SCORE: 7.311
#
#
# GENRE: Animation
# 1. Film: WALL·E       SCORE: 7.621
# 2. Film: Up       SCORE: 7.544
# 3. Film: Toy Story       SCORE: 7.503
# 4. Film: Finding Nemo       SCORE: 7.438
# 5. Film: Toy Story 3       SCORE: 7.392
#
#
# GENRE: Science Fiction
# 1. Film: Eternal Sunshine of the Spotless Mind       SCORE: 7.596
# 2. Film: Blade Runner       SCORE: 7.586
# 3. Film: 2001: A Space Odyssey       SCORE: 7.543
# 4. Film: The Avengers       SCORE: 7.323
# 5. Film: Star Trek       SCORE: 7.217
#
#
# GENRE: Drama
# 1. Film: The Shawshank Redemption       SCORE: 8.302
# 2. Film: The Godfather       SCORE: 8.143
# 3. Film: Fight Club       SCORE: 8.140
# 4. Film: The Dark Knight       SCORE: 8.078
# 5. Film: Schindler's List       SCORE: 7.979
#
#
# GENRE: Thriller
# 1. Film: Pulp Fiction       SCORE: 8.122
# 2. Film: Snatch       SCORE: 7.375
# 3. Film: Now You See Me       SCORE: 7.157
# 4. Film: Mulholland Drive       SCORE: 7.098
# 5. Film: Gattaca       SCORE: 7.092
#
#
# GENRE: Family
# 1. Film: The Lion King       SCORE: 7.770
# 2. Film: Wreck-It Ralph       SCORE: 6.960
# 3. Film: Willy Wonka & the Chocolate Factory       SCORE: 6.772
# 4. Film: Paddington       SCORE: 6.587
# 5. Film: The Jungle Book       SCORE: 6.577
#
#
# GENRE: Comedy
# 1. Film: Forrest Gump       SCORE: 8.021
# 2. Film: The Grand Budapest Hotel       SCORE: 7.732
# 3. Film: The Truman Show       SCORE: 7.561
# 4. Film: Amélie       SCORE: 7.489
# 5. Film: The Big Lebowski       SCORE: 7.456
#
#
# GENRE: History
# 1. Film: The Imitation Game       SCORE: 7.782
# 2. Film: Selma       SCORE: 6.780
# 3. Film: Butch Cassidy and the Sundance Kid       SCORE: 6.705
# 4. Film: Milk       SCORE: 6.549
# 5. Film: Lincoln       SCORE: 6.493
#
#
# GENRE: War
# 1. Film: American Sniper       SCORE: 7.215
# 2. Film: Fury       SCORE: 7.194
# 3. Film: The Boy in the Striped Pyjamas       SCORE: 7.158
# 4. Film: Enemy at the Gates       SCORE: 6.730
# 5. Film: Glory       SCORE: 6.539
#
#
# GENRE: Western
# 1. Film: The Good, the Bad and the Ugly       SCORE: 7.615
# 2. Film: Once Upon a Time in the West       SCORE: 7.307
# 3. Film: The Revenant       SCORE: 7.175
# 4. Film: Unforgiven       SCORE: 7.059
# 5. Film: A Fistful of Dollars       SCORE: 6.914
#
#
# GENRE: Romance
# 1. Film: Her       SCORE: 7.624
# 2. Film: The Notebook       SCORE: 7.388
# 3. Film: The Fault in Our Stars       SCORE: 7.353
# 4. Film: Groundhog Day       SCORE: 7.083
# 5. Film: Corpse Bride       SCORE: 6.890
#
#
# GENRE: Crime
# 1. Film: Se7en       SCORE: 7.872
# 2. Film: The Silence of the Lambs       SCORE: 7.814
# 3. Film: The Wolf of Wall Street       SCORE: 7.718
# 4. Film: Reservoir Dogs       SCORE: 7.683
# 5. Film: Taxi Driver       SCORE: 7.570
#
#
# GENRE: Mystery
# 1. Film: Memento       SCORE: 7.789
# 2. Film: Gone Girl       SCORE: 7.698
# 3. Film: The Sixth Sense       SCORE: 7.395
# 4. Film: Nerve       SCORE: 6.845
# 5. Film: Eyes Wide Shut       SCORE: 6.723
#
#
# GENRE: Horror
# 1. Film: The Shining       SCORE: 7.771
# 2. Film: Alien       SCORE: 7.644
# 3. Film: Aliens       SCORE: 7.401
# 4. Film: The Thing       SCORE: 7.259
# 5. Film: Jaws       SCORE: 7.184
#
#
# GENRE: Documentary
# 1. Film: Bowling for Columbine       SCORE: 6.552
# 2. Film: Inside Job       SCORE: 6.542
# 3. Film: One Direction: This Is Us       SCORE: 6.501
# 4. Film: The Act of Killing       SCORE: 6.404
# 5. Film: Food, Inc.       SCORE: 6.390
#
#
# GENRE: Music
# 1. Film: The Blues Brothers       SCORE: 6.924
# 2. Film: Step Up       SCORE: 6.451
# 3. Film: Step Up Revolution       SCORE: 6.380
# 4. Film: Team America: World Police       SCORE: 6.332
# 5. Film: Wayne's World       SCORE: 6.295
#
#
# GENRE: TV Movie
# 1. Film: We Have Your Husband       SCORE: 6.088
# 2. Film: Love's Abiding Joy       SCORE: 6.087
# 3. Film: Restless       SCORE: 6.079
# 4. Film: Sharknado       SCORE: 5.193
#
#
# GENRE: Foreign
# 1. Film: Burn       SCORE: 6.099
# 2. Film: Cavite       SCORE: 6.096

# %%
# Топ-5 каждого жанра с С = медиана

genres_array = []
ans_dict = dict()
for i in data['genres']:
    ggs = json.loads(i)
    if len(ggs) != 0:
        if ggs[0]["name"] not in genres_array:
            genres_array.append(ggs[0]["name"])
            ans_dict[ggs[0]["name"]] = []

for i in range(len(data)):
    j = data.loc[i]["genres"]
    ggs = json.loads(j)
    if len(ggs) != 0:
        ans_dict[ggs[0]["name"]].append(transform2(data.loc[i]))

for i in genres_array:
    ans_dict[i] = sorted(ans_dict[i], key=lambda film: film["score"])
    ans_dict[i].reverse()

print("Top 5 by genre(mediana):\n")
for i in genres_array:
    print("GENRE: {}".format(i))
    for j in range(min(5, len(ans_dict[i]))):
        print("{}. Film: {}       SCORE: {}".format(j+1, ans_dict[i][j]["name"], '%.3f' % ans_dict[i][j]["score"]))
    print('\n')
# Out:
# Top 5 by genre(mediana):
#
# GENRE: Action
# 1. Film: Inception       SCORE: 8.003
# 2. Film: Guardians of the Galaxy       SCORE: 7.780
# 3. Film: The Matrix       SCORE: 7.770
# 4. Film: Gladiator       SCORE: 7.697
# 5. Film: Scarface       SCORE: 7.640
#
#
# GENRE: Adventure
# 1. Film: Interstellar       SCORE: 7.979
# 2. Film: The Empire Strikes Back       SCORE: 7.977
# 3. Film: The Lord of the Rings: The Return of the King       SCORE: 7.941
# 4. Film: Star Wars       SCORE: 7.910
# 5. Film: The Lord of the Rings: The Fellowship of the Ring       SCORE: 7.860
#
#
# GENRE: Fantasy
# 1. Film: Spirited Away       SCORE: 7.962
# 2. Film: The Green Mile       SCORE: 7.892
# 3. Film: Howl's Moving Castle       SCORE: 7.660
# 4. Film: Donnie Darko       SCORE: 7.436
# 5. Film: How to Train Your Dragon 2       SCORE: 7.332
#
#
# GENRE: Animation
# 1. Film: WALL·E       SCORE: 7.632
# 2. Film: Up       SCORE: 7.555
# 3. Film: Toy Story       SCORE: 7.516
# 4. Film: Finding Nemo       SCORE: 7.450
# 5. Film: Toy Story 3       SCORE: 7.407
#
#
# GENRE: Science Fiction
# 1. Film: Eternal Sunshine of the Spotless Mind       SCORE: 7.615
# 2. Film: Blade Runner       SCORE: 7.605
# 3. Film: 2001: A Space Odyssey       SCORE: 7.565
# 4. Film: The Avengers       SCORE: 7.329
# 5. Film: Star Trek       SCORE: 7.232
#
#
# GENRE: Drama
# 1. Film: The Shawshank Redemption       SCORE: 8.310
# 2. Film: The Godfather       SCORE: 8.155
# 3. Film: Fight Club       SCORE: 8.148
# 4. Film: The Dark Knight       SCORE: 8.084
# 5. Film: Schindler's List       SCORE: 7.994
#
#
# GENRE: Thriller
# 1. Film: Pulp Fiction       SCORE: 8.131
# 2. Film: Snatch       SCORE: 7.397
# 3. Film: Now You See Me       SCORE: 7.170
# 4. Film: Mulholland Drive       SCORE: 7.134
# 5. Film: Gattaca       SCORE: 7.124
#
#
# GENRE: Family
# 1. Film: The Lion King       SCORE: 7.783
# 2. Film: Wreck-It Ralph       SCORE: 6.975
# 3. Film: Willy Wonka & the Chocolate Factory       SCORE: 6.824
# 4. Film: Paddington       SCORE: 6.636
# 5. Film: The Jungle Book       SCORE: 6.598
#
#
# GENRE: Comedy
# 1. Film: Forrest Gump       SCORE: 8.030
# 2. Film: The Grand Budapest Hotel       SCORE: 7.748
# 3. Film: The Truman Show       SCORE: 7.576
# 4. Film: Amélie       SCORE: 7.509
# 5. Film: The Big Lebowski       SCORE: 7.478
#
#
# GENRE: History
# 1. Film: The Imitation Game       SCORE: 7.795
# 2. Film: Selma       SCORE: 6.831
# 3. Film: Butch Cassidy and the Sundance Kid       SCORE: 6.762
# 4. Film: Milk       SCORE: 6.608
# 5. Film: Lincoln       SCORE: 6.530
#
#
# GENRE: War
# 1. Film: American Sniper       SCORE: 7.230
# 2. Film: Fury       SCORE: 7.211
# 3. Film: The Boy in the Striped Pyjamas       SCORE: 7.195
# 4. Film: Enemy at the Gates       SCORE: 6.775
# 5. Film: Glory       SCORE: 6.610
#
#
# GENRE: Western
# 1. Film: The Good, the Bad and the Ugly       SCORE: 7.641
# 2. Film: Once Upon a Time in the West       SCORE: 7.349
# 3. Film: The Revenant       SCORE: 7.186
# 4. Film: Unforgiven       SCORE: 7.102
# 5. Film: A Fistful of Dollars       SCORE: 6.963
#
#
# GENRE: Romance
# 1. Film: Her       SCORE: 7.641
# 2. Film: The Notebook       SCORE: 7.409
# 3. Film: The Fault in Our Stars       SCORE: 7.371
# 4. Film: Groundhog Day       SCORE: 7.109
# 5. Film: What's Eating Gilbert Grape       SCORE: 6.921
#
#
# GENRE: Crime
# 1. Film: Se7en       SCORE: 7.885
# 2. Film: The Silence of the Lambs       SCORE: 7.830
# 3. Film: The Wolf of Wall Street       SCORE: 7.729
# 4. Film: Reservoir Dogs       SCORE: 7.701
# 5. Film: Taxi Driver       SCORE: 7.595
#
#
# GENRE: Mystery
# 1. Film: Memento       SCORE: 7.806
# 2. Film: Gone Girl       SCORE: 7.710
# 3. Film: The Sixth Sense       SCORE: 7.415
# 4. Film: Nerve       SCORE: 6.873
# 5. Film: Eyes Wide Shut       SCORE: 6.763
#
#
# GENRE: Horror
# 1. Film: The Shining       SCORE: 7.788
# 2. Film: Alien       SCORE: 7.659
# 3. Film: Aliens       SCORE: 7.421
# 4. Film: The Thing       SCORE: 7.293
# 5. Film: Jaws       SCORE: 7.208
#
#
# GENRE: Documentary
# 1. Film: Inside Job       SCORE: 6.619
# 2. Film: Bowling for Columbine       SCORE: 6.619
# 3. Film: One Direction: This Is Us       SCORE: 6.586
# 4. Film: The Act of Killing       SCORE: 6.488
# 5. Film: Food, Inc.       SCORE: 6.473
#
#
# GENRE: Music
# 1. Film: The Blues Brothers       SCORE: 6.968
# 2. Film: Step Up       SCORE: 6.495
# 3. Film: Step Up Revolution       SCORE: 6.437
# 4. Film: Team America: World Police       SCORE: 6.389
# 5. Film: Jersey Boys       SCORE: 6.354
#
#
# GENRE: TV Movie
# 1. Film: We Have Your Husband       SCORE: 6.195
# 2. Film: Love's Abiding Joy       SCORE: 6.194
# 3. Film: Restless       SCORE: 6.186
# 4. Film: Sharknado       SCORE: 5.258
#
#
# GENRE: Foreign
# 1. Film: Burn       SCORE: 6.206
# 2. Film: Cavite       SCORE: 6.204
